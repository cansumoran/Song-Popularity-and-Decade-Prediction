# %% [markdown]
# Preprossesing includes 2 Parts: Data Selection and Data Preprocessing
#
# ---
#
# Data Selection: has the selection of english songs and three different elimination parameters from the original data to identify songs to retrieve lyrics for.
#
# Data Preprocessing: has lyrical data cleaning including stop word removals, lemmatization, tokenization and the creation of two different class labels: period and popularity per period.

# %% [markdown]
# #Mount Device#

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Imports and Installations#

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 13.1 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from langdetect) (1.15.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=3cd88357c6fee59385c9f93fd461c608b8c8284167b600032b9052cb3c9a5148
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
import pandas as pd
import os
import csv
import numpy as np

import nltk 
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from langdetect import detect

# %%
nltk.download("wordnet")
nltk.download("stopwords")
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# #Common Function Declarations#

# %%
# add period column
def label_period (row):
   return (( row['year'] // 10) % 10) * 10

# %%
# amount of songs in each period
def songs_per_period(df):
  value_count = df['period'].value_counts()
  print(value_count)
  print("Total sum: ", value_count.sum())

# %%
# total score of popular songs in each period
def get_popular_count(rows):
  return rows['popularity'].sum()

def pop_songs_per_period(df):
  for i in range(0,90,10):
    count = get_popular_count(df[df['period'] == i])
    print(i, ": ", count)

# %%
# detect language of songs based on name, artist using ML algo
def label_language(row):
  try:
    lang = detect(row['name'])
  except:
    #look for english artist name in unidentified song names
    try:
      lang = detect(row['artists'])
    except:
      lang = "error"
      print("This row throws and error:", row['name'], "Artist: ", row['artists'],"Date: ", row['year'])
  return lang
  
# detect language of a word
def get_lang(word):
  try:
    lang = detect(word)
  except:
    lang = "error"
  return lang

# %%
#Drop periods: 20s,30s,40s, and 50s
def drop_periods(df):
  for i in range(20, 51, 10):
    df = df[df['period'] != i]
  return df

# %%
def divide_by_period(df):
  periods = [60, 70, 80, 90, 0, 10]
  dataframes = []
  for i in range(6):
    df_period = pd.DataFrame()
    df_period = df[df["period"] == periods[i]]
    print(df_period)
    dataframes.append(df_period)
  return dataframes

# %% [markdown]
# #Data Selection#

# %%
# data.csv is the untouched Spotify data from Kaggle
root = '/content/gdrive/My Drive/machine learning/preprocessing'
csv_path = os.path.join(root, 'data.csv')
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    acousticness                                   artists  ...  valence  year
# 0         0.995                       ['Carl Woitschach']  ...   0.7790  1928
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']  ...   0.0767  1928
# 2         0.604                   ['Seweryn Goszczyński']  ...   0.8800  1928
# 3         0.995                      ['Francisco Canaro']  ...   0.7200  1928
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']  ...   0.0693  1928
#
# [5 rows x 19 columns]

# %%
df.shape[0] #row count
# Out:
# 169909

# %%
df['period'] = df.apply (lambda row: label_period(row), axis=1)
df['period'].unique()
# Out:
# array([20, 30, 40, 50, 60, 70, 80, 90,  0, 10])

# %%
#delete further unnecessary columns
df = df.drop(columns=['acousticness','danceability','duration_ms', 'energy', 
                      'explicit', 'key', 'liveness', 'loudness', 'mode', 'release_date',
                      'tempo', 'valence', 'year'])

# %%
# Three different tracks to select songs in the data
#TRACK 1: speechiness > 0.33      -> track = 2
#TRACK 2: instrumentalness < 0.5  -> track = 3 -> FOUND TO BE THE OPTIMAL SELECTION
#TRACK 3: instrumentalness < 0.5 AND speechiness > 0.33 -> track = 6

track = 3

# %%
# delete songs with not enough lyrics 
if track % 2 == 0:
  df_track = df[df['speechiness'] > 0.33]
  df_track = df_track[df_track['instrumentalness'] != 0.0]
  
if track % 3 == 0:
  df_track = df[df['instrumentalness'] < 0.5]

df_track.head()
# Out:
#                                    artists  ... period
# 2                  ['Seweryn Goszczyński']  ...     20
# 6     ['Franz Liszt', 'Vladimir Horowitz']  ...     20
# 8           ['Francisco Canaro', 'Charlo']  ...     20
# 9                  ['Seweryn Goszczyński']  ...     20
# 15  ['George Butterworth', 'John Cameron']  ...     20
#
# [5 rows x 7 columns]

# %%
# amount of songs in each period
print("IN DF:")
songs_per_period(df)
print("IN DF Track:")
songs_per_period(df_track)
# Out:
# IN DF:
# 90    20000
# 80    20000
# 70    20000
# 60    20000
# 0     20000
# 50    19950
# 10    19900
# 40    14968
# 30     8889
# 20     6202
# Name: period, dtype: int64
# Total sum:  169909
# IN DF Track:
# 10    18499
# 0     18446
# 90    17962
# 70    17847
# 80    17692
# 60    16738
# 50    14783
# 40     9083
# 30     6176
# 20     4140
# Name: period, dtype: int64
# Total sum:  141366

# %%
# USE IN CASE OF NEED -> TIME CONSUMING ALGORITHM
df_track['language'] = df_track.apply (lambda row: label_language(row), axis=1)
df_track.to_csv('df_lang.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# READ from already languaged data
df_track = pd.read_csv('df_lang.csv', index_col=0)

# %%
# Information about the languages in the current data
value_count = df_track['language'].value_counts()
print(value_count)
# Out:
# en       76545
# de        9722
# es        7072
# it        5019
# pt        3990
# fr        3935
# id        3421
# tl        3129
# nl        3006
# af        2263
# ru        1996
# so        1894
# no        1792
# ca        1683
# sw        1677
# ro        1498
# da        1422
# cy        1314
# fi        1296
# et        1167
# tr        1044
# pl         974
# sv         829
# ko         623
# sl         554
# lt         532
# el         513
# hu         392
# hr         388
# sk         367
# vi         242
# sq         241
# cs         235
# zh-cn      184
# zh-tw       99
# lv          98
# ja          74
# he          43
# ar          41
# uk          35
# bg           6
# mk           5
# fa           3
# th           3
# Name: language, dtype: int64

# %%
# Only get EN songs
df_track = df_track[df_track['language'] == 'en']

print("IN DF Track:")
songs_per_period(df_track)
# Out:
# IN DF Track:
# 70    11816
# 80    10982
# 60    10832
# 0     10177
# 10    10136
# 90     9769
# 50     7046
# 40     2428
# 30     1917
# 20     1442
# Name: period, dtype: int64
# Total sum:  76545

# %%
# Drop column no longer needed
df_track = df_track.drop(columns=['language', 'instrumentalness', 'speechiness'])

# %%
#Drop periods: 20s,30s,40s, and 50s
df_track = drop_periods(df_track)

# %%
df_track.head()
# Out:
#                                                 artists  ... period
# 2055  ['John Hughes', 'Frank Asper', 'Mormon Taberna...  ...     60
# 2056                                 ['Frankie Avalon']  ...     60
# 2057                            ['The Everly Brothers']  ...     60
# 2058  ['John Bacchus Dykes', 'Mormon Tabernacle Choi...  ...     60
# 2059                            ['The Everly Brothers']  ...     60
#
# [5 rows x 5 columns]

# %%
# WRITE to CSV
df_track.to_csv('df_eng.csv')

# %% [markdown]
# #Data Preprocessing#

# %%
#READ lyrical data
csv_path = '/content/gdrive/MyDrive/machine learning/preprocessing/lyrics.csv'
lyrical_df = pd.read_csv(csv_path, index_col=0)
lyrical_df.head()
# Out:
#                    artists  ...                                             lyrics
# 0       ['Frankie Avalon']  ...  A boy without a girl\nIs a song without a tune...
# 1  ['The Everly Brothers']  ...  The sweet sweet memories you gave-a me\nYou ca...
# 2    ['Annette Funicello']  ...  How will I know my love?\nHow will I know my d...
# 3          ['Chuck Berry']  ...  Baby, here I stand before you\nWith my heart i...
# 4         ['Elmore James']  ...  Shake your moneymaker\nShake your moneymaker\n...
#
# [5 rows x 6 columns]

# %%
# remove any nan lyrics from the data
songs_per_period(lyrical_df)

lyrical_df.replace('', np.nan, inplace = True)
lyrical_df = lyrical_df.dropna()

songs_per_period(lyrical_df)
# Out:
# 70.0    7978
# 80.0    7298
# 90.0    5740
# 0.0     5137
# 60.0    4738
# 10.0    4426
# Name: period, dtype: int64
# Total sum:  35317
# 70.0    7380
# 80.0    6777
# 90.0    5280
# 0.0     4811
# 60.0    4152
# 10.0    4126
# Name: period, dtype: int64
# Total sum:  32526

# %%
# check if lyrics contain floats
df_num = lyrical_df.select_dtypes(include=[np.float])
print(df_num)
# Out:
#       popularity  period
# 0           13.0    60.0
# 1           14.0    60.0
# 2           11.0    60.0
# 3           20.0    60.0
# 4           14.0    60.0
# ...          ...     ...
# 4030        59.0    10.0
# 4031        59.0    10.0
# 4032        58.0    10.0
# 4033        61.0    10.0
# 4034        67.0    10.0
#
# [32526 rows x 2 columns]

# %% [markdown]
# **TOKENIZATION OF LYRICAL DATA**

# %%
def remove_punc(df):
  #remove punctuations and turn case to lower
  df['lyrics'] = df.apply (lambda row: " ".join(re.findall("[\w][\w]+", row['lyrics'])).lower(), axis=1)
  #reduce multiple space to single space
  df['lyrics'] = df.apply (lambda row: re.sub('[\s]+', ' ', row['lyrics']), axis=1)
  return df

lyrical_df = remove_punc(lyrical_df)
lyrical_df.head()
# Out:
#                    artists  ...                                             lyrics
# 0       ['Frankie Avalon']  ...  boy without girl is song without tune is year ...
# 1  ['The Everly Brothers']  ...  the sweet sweet memories you gave me you can b...
# 2    ['Annette Funicello']  ...  how will know my love how will know my darlin ...
# 3          ['Chuck Berry']  ...  baby here stand before you with my heart in my...
# 4         ['Elmore James']  ...  shake your moneymaker shake your moneymaker sh...
#
# [5 rows x 6 columns]

# %%
#NEW stopwords list for song lyrics
def get_stopwords(print=False):
  lyrical_stopwords = list()
  lyrical_stopwords = stopwords.words("english")
  lyrical_stopwords.extend(["verse", "intro", "chorus"])
  return lyrical_stopwords

#global list to be used following functions
lyrical_stopwords = get_stopwords()
stopwords_set = set()

# %%
#Remove stops words & lemmatize
def clean_data(str, get_remove_words=False, eng_word=False):
  lemmatizer = WordNetLemmatizer()
  tokens = nltk.word_tokenize(str)

  remove_stopwords = list(filter(lambda token: token not in lyrical_stopwords,tokens))
  lemmatized_words = [lemmatizer.lemmatize(word) for word in remove_stopwords]
  if eng_word:
    lemmatized_words = [word for word in lemmatized_words if get_lang(word) == 'en']

  if get_remove_words:
    #collecting all removed words in a set
    removed_words = list(filter(lambda token: token in lyrical_stopwords,tokens))
    global stopwords_set
    for word in removed_words:
      stopwords_set.add(word)
  return " ".join(lemmatized_words)

lyrical_df['lyrics'] = lyrical_df.apply(lambda row: clean_data(row['lyrics']), axis=1)
lyrical_df.head()
# Out:
#                    artists  ...                                             lyrics
# 0       ['Frankie Avalon']  ...  boy without girl song without tune year withou...
# 1  ['The Everly Brothers']  ...  sweet sweet memory gave beat memory gave take ...
# 2    ['Annette Funicello']  ...  know love know darlin whippoorwill give sign k...
# 3          ['Chuck Berry']  ...  baby stand heart hand put mama hoping understa...
# 4         ['Elmore James']  ...  shake moneymaker shake moneymaker shake moneym...
#
# [5 rows x 6 columns]

# %%
# clean from nan values again
lyrical_df.replace('', np.nan, inplace = True)
lyrical_df = lyrical_df.dropna()
print(lyrical_df.shape[0])
# Out:
# 32507

# %%
# WRITE processed lyrical data
lyrical_df.to_csv('/content/gdrive/MyDrive/machine learning/preprocessing/LYRICS_PROCESSED.csv', index=False)

# %% [markdown]
# #Transforming Processed Data For Models

# %%
csv_path = '/content/gdrive/MyDrive/machine learning/preprocessing/LYRICS_PROCESSED.csv'
lyrical_df = pd.read_csv(csv_path, index_col=0)
lyrical_df.head()
# Out:
#                                              id  ...                                             lyrics
# artists                                          ...
# ['Frankie Avalon']       0CUsZyJMSDjhdoQZxHhTtx  ...  boy without girl song without tune year withou...
# ['The Everly Brothers']  0YBFwnejhmHiukKks1U3xu  ...  sweet sweet memory gave beat memory gave take ...
# ['Annette Funicello']    1kOKcxYSK4FID1apuNV8qe  ...  know love know darlin whippoorwill give sign k...
# ['Chuck Berry']          26VeLcnNOv7iOtzb7VuHZF  ...  baby stand heart hand put mama hoping understa...
# ['Elmore James']         2cr2rjdV2JOz1J0prTiPOG  ...  shake moneymaker shake moneymaker shake moneym...
#
# [5 rows x 5 columns]

# %%
dataframes = divide_by_period(lyrical_df)
# Out:
#                                              id  ...                                             lyrics
# artists                                          ...
# ['Frankie Avalon']       0CUsZyJMSDjhdoQZxHhTtx  ...  boy without girl song without tune year withou...
# ['The Everly Brothers']  0YBFwnejhmHiukKks1U3xu  ...  sweet sweet memory gave beat memory gave take ...
# ['Annette Funicello']    1kOKcxYSK4FID1apuNV8qe  ...  know love know darlin whippoorwill give sign k...
# ['Chuck Berry']          26VeLcnNOv7iOtzb7VuHZF  ...  baby stand heart hand put mama hoping understa...
# ['Elmore James']         2cr2rjdV2JOz1J0prTiPOG  ...  shake moneymaker shake moneymaker shake moneym...
# ...                                         ...  ...                                                ...
# ['Percy Sledge']         3yjuIBV7rnHvoPlMRjgis1  ...  living living living ohhhh nobody else nobody ...
# ['Frank Sinatra']        13qzHYbEqzcq34eZzYsKIs  ...  town lonely town town like town town make town...
# ['Jefferson Airplane']   1xTyfejmnulYD3fO390sz9  ...  lady keep asking like come wonder want boy got...
# ['The Band']             7aTCCNpHJD2Jgv0LLVJb8Y  ...  get mountain know want go straight mississippi...
# ['The Woolies']          615QoDLpyIODGVvHEPP4pt  ...  walk 47 mile bob wire use cobra snake necktie ...
#
# [4151 rows x 5 columns]
#                                                id  ...                                             lyrics
# artists                                            ...
# ['Elton John']             2AgMTn4RyRrI1uc3iXx4Xq  ...  day father gun dug shallow grave beneath sun l...
# ['Willie Dixon']           4iKp3icJChjTFQBYbydH43  ...  well quit baby got put little well quit baby g...
# ['James Gang']             0OgWuPs6lyCnnLUw1INrdQ  ...  dale peter jim fox joe walsh woman hearin bout...
# ['Van Morrison']           2Jq8mmOqBh1Raf6vi3nQZk  ...  hey pencil microphone pencil directional one t...
# ['Deep Purple']            6nt9Sx2NEOYDO23MO4UCIC  ...  got ta black breast chinese eye got english br...
# ...                                           ...  ...                                                ...
# ['John Denver']            1hjNIcn5cvl9x8U44xUMqE  ...  di di di di di la la la la la la spaceship mou...
# ['Dan Hartman']            0E1PR66A94yVPiYJxGHimf  ...  10 aaah set lip fire key heart got special way...
# ['Waylon Jennings']        5H4wGQLp7OFGOy43DXtIOJ  ...  lord old tune fiddle guitar take rhinestone su...
# ['Donna Summer']           74aa4XTCUlLkEArligz0i7  ...  dim light sweet darling cause tonight way turn...
# ['Narada Michael Walden']  0PjkD419FrFnRuS5Mgs6pm  ...  shoulda loved ya shoulda loved ya ooh touched ...
#
# [7374 rows x 5 columns]
#                                             id  ...                                             lyrics
# artists                                         ...
# ['Con Funk Shun']       5wlLvQGAxVkHCCSaRWqwsJ  ...  need worry love hurry take time love side ooh ...
# ["The B-52's"]          16DzN7oEYy3d5NvUomglGr  ...  help devil car help devil car help devil car h...
# ['Roxy Music']          0Gy2Mq49a3qb79jwlEa59o  ...  ever wonder word say heaven know hard enough p...
# ['X']                   1AtDRZnb4rQiTNZGNcBRPc  ...  one united thing untied perhaps boiling inside...
# ['The Rolling Stones']  1E7ApSN0hYXE1QHdx4ogxf  ...  little indian girl mama little indian girl pap...
# ...                                        ...  ...                                                ...
# ['Tina Turner']         3dYmruq1HiKJeOQ8h1OEfz  ...  thinking parking night back road baby getting ...
# ['KISS']                47o525G86mLspoGnUCaMd9  ...  johnny saw riding street car named desire fate...
# ['Eric Clapton']        0MSBMSfQzkfG5jq8e4vTE1  ...  oh feeling get take heart everything make sad ...
# ['Dionne Warwick']      25kYvXbKVoh3oQD3OwozhK  ...  looked inside fantasy made one come true somet...
# ['KISS']                7gAHDwN4iqkjFozSODtWBn  ...  style gone waste beauty never show face going ...
#
# [6769 rows x 5 columns]
#                                                          id  ...                                             lyrics
# artists                                                      ...
# ['Paul Simon']                       1RxlMG0bJhJdR5H6wL2oJf  ...  feel good fine day way sun hit runway cloud sh...
# ['Concrete Blonde']                  30q9tmV1f3vHli0MhHtZR9  ...  complete two end time neatly tied one way stre...
# ['Roberta Flack', 'Donny Hathaway']  0vB3z9Jp1OFTV9gZDYkVG1  ...  know may never meet go make moment sweet say g...
# ['Uncle Tupelo']                     4GGvLe0rAVoqGIg7aZnxBC  ...  hometown town blue old wall closing oh life me...
# ['Gregory Isaacs']                   7bNG4xcrAgis8Hos2eNDz0  ...  gon na lay bright early cause heat know ready ...
# ...                                                     ...  ...                                                ...
# ['Mint Condition']                   3VZMAx8GdrO73kvTZDD8rU  ...  love like say wonâ show much love unconditiona...
# ['Joe Diffie']                       7rGFyfE73J6lkEvFnCHucC  ...  downtown stoplight red car roll else wonder sc...
# ['Stevie Wonder']                    6FzuAWhUUkMPiv7LTLGFgE  ...  girl think fine soon mind girl think smart soo...
# ['Pure Prairie League']              0tcq9tNIw5JHUywymB07OA  ...  soon time go want leave guess know maybe somet...
# ['The Who']                          6JNVCUi0TUeNFVLvyXFJfN  ...  hear sound comin hear drummer drumming join to...
#
# [5278 rows x 5 columns]
#                                                                         id  ...                                             lyrics
# artists                                                                     ...
# ['Etta James']                                      4JVeqfE2tpi7Pv63LJZtPh  ...  holding long sleeping alone cause miss hanging...
# ['Prodigy', 'Nas']                                  0SlljMy4uEgoVPCyavtcHH  ...  yo ill need fixed shit real dunn stop talkin l...
# ['The Peasall Sisters']                             49rEKkP4P0nKhxMdPxaYzP  ...  highway hedge highway hedge highway hedge some...
# ['The Cathedral Singers', 'Lorelei McDermott', ...  4IyK8htJJzbRjPihpMouWu  ...  ave maria gratia plenum dominus tecum benedict...
# ['The Clarks']                                      1liqxWv5Stjdtor4n3S9cZ  ...  vincent teach paint theresa ever saint john re...
# ...                                                                    ...  ...                                                ...
# ['Aaron Neville']                                   7GSRH3L0HAM3StkAkYVamC  ...  want something play go find toy baby time expe...
# ['Eli Young Band']                                  3RFwzA2lXqIzoXHVbeLH1d  ...  used pull highway 249 cool little place go hid...
# ['Metallica']                                       6qIleHbUTXcGfBfQ8h0R2n  ...  claustrophobic crawl skin hard explosive reach...
# ['Toby Keith']                                      4cG1Bu2EdPA9KqrOCviKP0  ...  trying father raise daughter son lover mother ...
# ['Jonas Brothers']                                  7xZa00kpFR3r7UqeczbVPE  ...  joe jonas well throwing punch line one win mor...
#
# [4809 rows x 5 columns]
#                                                         id  ...                                             lyrics
# artists                                                     ...
# ['Tame Impala']                     4m3GHOgCNZMv0we7H9j8Y8  ...  everything ever told could lie may never love ...
# ['Bring Me The Horizon']            0ZxZsjMMyLgjRV1XLWlIaS  ...  started one night stand lingered fling siren s...
# ['10 Years']                        6TghWaPh1WHJKWXow7iujH  ...  shoot shoot cause want want shoot shoot cause ...
# ['The Steeldrivers']                5LfDOTMc5zVt3RLvLkme3L  ...  music playing whiskey saloon come window like ...
# ['Ellie Goulding']                  1vWGa8yC21ZELs9dAhiC2Q  ...  handle bar let go let go anyone take throw hea...
# ...                                                    ...  ...                                                ...
# ['J. Cole']                         77IAeEz8LEchPN8UNjaTJ2  ...  hey hey hey hey hey hey hook wan na fold cloth...
# ['Artists Of Then, Now & Forever']  3WWVDPjihd1VITBLF10nha  ...  brad paisley keith urban tim mcgraw faith hill...
# ['J. Cole']                         5rmcjZTrE9JR1YrbNZDFNW  ...  catch catch catch fallen love first time bridg...
# ['Blake Shelton']                   5slddJ629YcePvqD6Uyk8r  ...  daddy drove wheel flatbed ford fly found hole ...
# ['Khalid']                          5A1w94uzc1kO1Zhe8WWxC3  ...  power got sittin phone iâ waiting hour line se...
#
# [4126 rows x 5 columns]

# %%
# mean of popular songs in each period
def label_popularity(row, mean):
    return 1 if row["popularity"] > mean else 0

# %%
MAX_SONGS_PER_PERIOD = 4200
balanced = list()
for dataframe in dataframes:
  if dataframe.shape[0] > MAX_SONGS_PER_PERIOD:
    df = dataframe.iloc[:MAX_SONGS_PER_PERIOD]
  else:
    df = dataframe
  
  mean = df['popularity'].mean()
  print(df['period'].iloc[0], ": ", mean)
  df["pop_class"] = df.apply(lambda row: label_popularity(row, mean), axis=1)
  balanced.append(df)

balanced
# Out:
# 60.0 :  28.33341363526861
# 70.0 :  32.342619047619046
# 80.0 :  35.22952380952381
# 90.0 :  42.499761904761904
# 0.0 :  48.12880952380952
# 10.0 :  58.44013572467281
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# [                                             id  ... pop_class
#  artists                                          ...
#  ['Frankie Avalon']       0CUsZyJMSDjhdoQZxHhTtx  ...         0
#  ['The Everly Brothers']  0YBFwnejhmHiukKks1U3xu  ...         0
#  ['Annette Funicello']    1kOKcxYSK4FID1apuNV8qe  ...         0
#  ['Chuck Berry']          26VeLcnNOv7iOtzb7VuHZF  ...         0
#  ['Elmore James']         2cr2rjdV2JOz1J0prTiPOG  ...         0
#  ...                                         ...  ...       ...
#  ['Percy Sledge']         3yjuIBV7rnHvoPlMRjgis1  ...         1
#  ['Frank Sinatra']        13qzHYbEqzcq34eZzYsKIs  ...         1
#  ['Jefferson Airplane']   1xTyfejmnulYD3fO390sz9  ...         1
#  ['The Band']             7aTCCNpHJD2Jgv0LLVJb8Y  ...         0
#  ['The Woolies']          615QoDLpyIODGVvHEPP4pt  ...         1
#
#  [4151 rows x 6 columns],
#                                                           id  ... pop_class
#  artists                                                      ...
#  ['Elton John']                       2AgMTn4RyRrI1uc3iXx4Xq  ...         0
#  ['Willie Dixon']                     4iKp3icJChjTFQBYbydH43  ...         1
#  ['James Gang']                       0OgWuPs6lyCnnLUw1INrdQ  ...         0
#  ['Van Morrison']                     2Jq8mmOqBh1Raf6vi3nQZk  ...         0
#  ['Deep Purple']                      6nt9Sx2NEOYDO23MO4UCIC  ...         0
#  ...                                                     ...  ...       ...
#  ['Pink Floyd']                       21L1dVOTGhvAKvBXXnTIHj  ...         1
#  ['Johnny Cash', 'June Carter Cash']  1UN6NjkwkztYxl6XzIp0pJ  ...         1
#  ['Yusuf / Cat Stevens']              4QEeLo0E9yoBWCFAfaXhRc  ...         1
#  ['Badfinger']                        0wb21I1NV5uVUolRXIqlJF  ...         1
#  ['Jimmy Cliff']                      1dZxI6OuzwJ283y3gOU1Kq  ...         1
#
#  [4200 rows x 6 columns],
#                                              id  ... pop_class
#  artists                                         ...
#  ['Con Funk Shun']       5wlLvQGAxVkHCCSaRWqwsJ  ...         0
#  ["The B-52's"]          16DzN7oEYy3d5NvUomglGr  ...         0
#  ['Roxy Music']          0Gy2Mq49a3qb79jwlEa59o  ...         1
#  ['X']                   1AtDRZnb4rQiTNZGNcBRPc  ...         0
#  ['The Rolling Stones']  1E7ApSN0hYXE1QHdx4ogxf  ...         0
#  ...                                        ...  ...       ...
#  ['John Mellencamp']     3PL9ZdC0ldyFrWZnPD4iPH  ...         1
#  ['Tears For Fears']     23DKn3AP0fpx1aAYth2Pax  ...         1
#  ['Steve Wariner']       4yzsRBx1S15iFaexzWKljO  ...         1
#  ['Rush']                3uQDfCKlwfK9Yz10JFcsC7  ...         1
#  ['Eagles']              52LAN8RKkM2qdIKTqVdIUg  ...         1
#
#  [4200 rows x 6 columns],
#                                                                          id  ... pop_class
#  artists                                                                     ...
#  ['Paul Simon']                                      1RxlMG0bJhJdR5H6wL2oJf  ...         0
#  ['Concrete Blonde']                                 30q9tmV1f3vHli0MhHtZR9  ...         0
#  ['Roberta Flack', 'Donny Hathaway']                 0vB3z9Jp1OFTV9gZDYkVG1  ...         0
#  ['Uncle Tupelo']                                    4GGvLe0rAVoqGIg7aZnxBC  ...         0
#  ['Gregory Isaacs']                                  7bNG4xcrAgis8Hos2eNDz0  ...         0
#  ...                                                                    ...  ...       ...
#  ['Keith Sweat']                                     16XILo6zHPXTr9NKgzzLJ4  ...         0
#  ['Shabba Ranks', 'Chevelle Franklin', 'David Mo...  4NzZftBCbGpXhca5OcfFwF  ...         1
#  ['Rollins Band']                                    1kUvgaQP1mBjifqRitiYah  ...         0
#  ['MC Serch']                                        7rxeH2yGlCeDKEkNNTpY29  ...         1
#  ['Stone Temple Pilots']                             4PUFrFCIuGy7qpoA8JyE7v  ...         0
#
#  [4200 rows x 6 columns],
#                                                                          id  ... pop_class
#  artists                                                                     ...
#  ['Etta James']                                      4JVeqfE2tpi7Pv63LJZtPh  ...         1
#  ['Prodigy', 'Nas']                                  0SlljMy4uEgoVPCyavtcHH  ...         0
#  ['The Peasall Sisters']                             49rEKkP4P0nKhxMdPxaYzP  ...         0
#  ['The Cathedral Singers', 'Lorelei McDermott', ...  4IyK8htJJzbRjPihpMouWu  ...         1
#  ['The Clarks']                                      1liqxWv5Stjdtor4n3S9cZ  ...         0
#  ...                                                                    ...  ...       ...
#  ['Steam']                                           1mrSHPNTDdMkXpR4BiSiD7  ...         0
#  ['Kenny Rogers']                                    16WtiQMxCjXlQc0hlbJbIQ  ...         1
#  ['Lily Allen']                                      7bW6MqAdTclmHVHAOkIyPS  ...         0
#  ['Commodores']                                      7l3QyhptrvjiNS5dOcUQvr  ...         0
#  ['John Paul Young']                                 3c4OULLWwgRqBfA2dJtRuY  ...         1
#
#  [4200 rows x 6 columns],
#                                                          id  ... pop_class
#  artists                                                     ...
#  ['Tame Impala']                     4m3GHOgCNZMv0we7H9j8Y8  ...         0
#  ['Bring Me The Horizon']            0ZxZsjMMyLgjRV1XLWlIaS  ...         0
#  ['10 Years']                        6TghWaPh1WHJKWXow7iujH  ...         0
#  ['The Steeldrivers']                5LfDOTMc5zVt3RLvLkme3L  ...         0
#  ['Ellie Goulding']                  1vWGa8yC21ZELs9dAhiC2Q  ...         0
#  ...                                                    ...  ...       ...
#  ['J. Cole']                         77IAeEz8LEchPN8UNjaTJ2  ...         1
#  ['Artists Of Then, Now & Forever']  3WWVDPjihd1VITBLF10nha  ...         1
#  ['J. Cole']                         5rmcjZTrE9JR1YrbNZDFNW  ...         0
#  ['Blake Shelton']                   5slddJ629YcePvqD6Uyk8r  ...         1
#  ['Khalid']                          5A1w94uzc1kO1Zhe8WWxC3  ...         1
#
#  [4126 rows x 6 columns]]

# %%
# Write data per period
for df in balanced:
  period_name = int(df.iloc[0]["period"])
  filename = '/content/gdrive/My Drive/machine learning/DATA/per_period/period_' + str(period_name) + '.csv'
  df.to_csv(filename, index=False)

# %%
balanced = pd.concat(balanced)

# %%
# Write all data
balanced.to_csv('/content/gdrive/My Drive/machine learning/DATA/BALANCED.csv', index=False)

# %%
# EXTRA INFO
dataframes = divide_by_period(balanced)
for dataframe in dataframes:
    print(int(dataframe.iloc[0]["period"]))
    min = 100000
    max = 0
    total = 0
    index_max = 0
    index_min = 0
    count = 0
    for i in range(dataframe.shape[0]):
      lyrics = dataframe.iloc[i]["lyrics"]
      if(lyrics == "instrumental"):
        count += 1
      words = lyrics.split()
      number_of_words = len(words)
      if number_of_words <= min:
        min = number_of_words
        index_min = i
      if number_of_words >= max:
        max = number_of_words
        index_max = i
      total += number_of_words
    print("Max: ", max)
    print("Min: ", min)
    average = total / dataframe.shape[0]
    print("Avg: ", average)
    print("instrumental count: ", count)
# Out:
#                                              id  ... pop_class
# artists                                          ...
# ['Frankie Avalon']       0CUsZyJMSDjhdoQZxHhTtx  ...         0
# ['The Everly Brothers']  0YBFwnejhmHiukKks1U3xu  ...         0
# ['Annette Funicello']    1kOKcxYSK4FID1apuNV8qe  ...         0
# ['Chuck Berry']          26VeLcnNOv7iOtzb7VuHZF  ...         0
# ['Elmore James']         2cr2rjdV2JOz1J0prTiPOG  ...         0
# ...                                         ...  ...       ...
# ['Percy Sledge']         3yjuIBV7rnHvoPlMRjgis1  ...         1
# ['Frank Sinatra']        13qzHYbEqzcq34eZzYsKIs  ...         1
# ['Jefferson Airplane']   1xTyfejmnulYD3fO390sz9  ...         1
# ['The Band']             7aTCCNpHJD2Jgv0LLVJb8Y  ...         0
# ['The Woolies']          615QoDLpyIODGVvHEPP4pt  ...         1
#
# [4151 rows x 6 columns]
#                                                          id  ... pop_class
# artists                                                      ...
# ['Elton John']                       2AgMTn4RyRrI1uc3iXx4Xq  ...         0
# ['Willie Dixon']                     4iKp3icJChjTFQBYbydH43  ...         1
# ['James Gang']                       0OgWuPs6lyCnnLUw1INrdQ  ...         0
# ['Van Morrison']                     2Jq8mmOqBh1Raf6vi3nQZk  ...         0
# ['Deep Purple']                      6nt9Sx2NEOYDO23MO4UCIC  ...         0
# ...                                                     ...  ...       ...
# ['Pink Floyd']                       21L1dVOTGhvAKvBXXnTIHj  ...         1
# ['Johnny Cash', 'June Carter Cash']  1UN6NjkwkztYxl6XzIp0pJ  ...         1
# ['Yusuf / Cat Stevens']              4QEeLo0E9yoBWCFAfaXhRc  ...         1
# ['Badfinger']                        0wb21I1NV5uVUolRXIqlJF  ...         1
# ['Jimmy Cliff']                      1dZxI6OuzwJ283y3gOU1Kq  ...         1
#
# [4200 rows x 6 columns]
#                                             id  ... pop_class
# artists                                         ...
# ['Con Funk Shun']       5wlLvQGAxVkHCCSaRWqwsJ  ...         0
# ["The B-52's"]          16DzN7oEYy3d5NvUomglGr  ...         0
# ['Roxy Music']          0Gy2Mq49a3qb79jwlEa59o  ...         1
# ['X']                   1AtDRZnb4rQiTNZGNcBRPc  ...         0
# ['The Rolling Stones']  1E7ApSN0hYXE1QHdx4ogxf  ...         0
# ...                                        ...  ...       ...
# ['John Mellencamp']     3PL9ZdC0ldyFrWZnPD4iPH  ...         1
# ['Tears For Fears']     23DKn3AP0fpx1aAYth2Pax  ...         1
# ['Steve Wariner']       4yzsRBx1S15iFaexzWKljO  ...         1
# ['Rush']                3uQDfCKlwfK9Yz10JFcsC7  ...         1
# ['Eagles']              52LAN8RKkM2qdIKTqVdIUg  ...         1
#
# [4200 rows x 6 columns]
#                                                                         id  ... pop_class
# artists                                                                     ...
# ['Paul Simon']                                      1RxlMG0bJhJdR5H6wL2oJf  ...         0
# ['Concrete Blonde']                                 30q9tmV1f3vHli0MhHtZR9  ...         0
# ['Roberta Flack', 'Donny Hathaway']                 0vB3z9Jp1OFTV9gZDYkVG1  ...         0
# ['Uncle Tupelo']                                    4GGvLe0rAVoqGIg7aZnxBC  ...         0
# ['Gregory Isaacs']                                  7bNG4xcrAgis8Hos2eNDz0  ...         0
# ...                                                                    ...  ...       ...
# ['Keith Sweat']                                     16XILo6zHPXTr9NKgzzLJ4  ...         0
# ['Shabba Ranks', 'Chevelle Franklin', 'David Mo...  4NzZftBCbGpXhca5OcfFwF  ...         1
# ['Rollins Band']                                    1kUvgaQP1mBjifqRitiYah  ...         0
# ['MC Serch']                                        7rxeH2yGlCeDKEkNNTpY29  ...         1
# ['Stone Temple Pilots']                             4PUFrFCIuGy7qpoA8JyE7v  ...         0
#
# [4200 rows x 6 columns]
#                                                                         id  ... pop_class
# artists                                                                     ...
# ['Etta James']                                      4JVeqfE2tpi7Pv63LJZtPh  ...         1
# ['Prodigy', 'Nas']                                  0SlljMy4uEgoVPCyavtcHH  ...         0
# ['The Peasall Sisters']                             49rEKkP4P0nKhxMdPxaYzP  ...         0
# ['The Cathedral Singers', 'Lorelei McDermott', ...  4IyK8htJJzbRjPihpMouWu  ...         1
# ['The Clarks']                                      1liqxWv5Stjdtor4n3S9cZ  ...         0
# ...                                                                    ...  ...       ...
# ['Steam']                                           1mrSHPNTDdMkXpR4BiSiD7  ...         0
# ['Kenny Rogers']                                    16WtiQMxCjXlQc0hlbJbIQ  ...         1
# ['Lily Allen']                                      7bW6MqAdTclmHVHAOkIyPS  ...         0
# ['Commodores']                                      7l3QyhptrvjiNS5dOcUQvr  ...         0
# ['John Paul Young']                                 3c4OULLWwgRqBfA2dJtRuY  ...         1
#
# [4200 rows x 6 columns]
#                                                         id  ... pop_class
# artists                                                     ...
# ['Tame Impala']                     4m3GHOgCNZMv0we7H9j8Y8  ...         0
# ['Bring Me The Horizon']            0ZxZsjMMyLgjRV1XLWlIaS  ...         0
# ['10 Years']                        6TghWaPh1WHJKWXow7iujH  ...         0
# ['The Steeldrivers']                5LfDOTMc5zVt3RLvLkme3L  ...         0
# ['Ellie Goulding']                  1vWGa8yC21ZELs9dAhiC2Q  ...         0
# ...                                                    ...  ...       ...
# ['J. Cole']                         77IAeEz8LEchPN8UNjaTJ2  ...         1
# ['Artists Of Then, Now & Forever']  3WWVDPjihd1VITBLF10nha  ...         1
# ['J. Cole']                         5rmcjZTrE9JR1YrbNZDFNW  ...         0
# ['Blake Shelton']                   5slddJ629YcePvqD6Uyk8r  ...         1
# ['Khalid']                          5A1w94uzc1kO1Zhe8WWxC3  ...         1
#
# [4126 rows x 6 columns]
# 60
# Max:  21127
# Min:  1
# Avg:  46.285714285714285
# instrumental count:  3
# 70
# Max:  341
# Min:  2
# Avg:  36.853809523809524
# instrumental count:  0
# 80
# Max:  330
# Min:  2
# Avg:  40.488571428571426
# instrumental count:  0
# 90
# Max:  264
# Min:  1
# Avg:  48.75595238095238
# instrumental count:  0
# 0
# Max:  4276
# Min:  1
# Avg:  50.81142857142857
# instrumental count:  0
# 10
# Max:  1526
# Min:  2
# Avg:  66.55138148327678
# instrumental count:  0
